# %% [markdown]
# # Machine Learning HW1: misc.

# %% [markdown]
# ## Exo 1: Gradient Descent

# %%
x = [1.0,1.0]
function f(x)
    x[1]^2 + x[2]^2
end
# Out:
# f (generic function with 1 method)

# %%
function derivative(f::function, x, var, epsilon)
    e = x*0 
    e[var] = epsilon
    y = x + e    
    (f(y) - f(x))/epsilon
end
# Out:
# derivative (generic function with 1 method)

# %%
function gradient(f::function,x,epsilon)
    grad = x*0
    for i in [1:size(x)[1];]
        grad[i] = derivative(f, x, i, epsilon)
    end
    grad
end
# Out:
# gradient (generic function with 1 method)

# %%
function gradientDescent(f, x_ini, step, stop)
    x1 = x_ini
    y0 = f(x1)
    y1 = f(x1) + stop + 1
    iterMax = 100
    nbIter = 0
    println(y0)
    hist  = DataFrame(X = Float64[], Y = Float64[])
    push!(hist, [x1[1], x1[2] ])
    while (abs(y1 - y0) >= stop) && (nbIter <= iterMax)
        nbIter += 1
        grad = gradient(f, x1, min(stop, step)/10)
        x0 = x1
        x1 = x0 - step*grad
        y0 = f(x0)
        y1 = f(x1)
        push!(hist, [x1[1], x1[2]])
    end
    return(hist)
end
# Out:
# gradientDescent (generic function with 1 method)

# %%
x
# Out:
# 2-element Array{Float64,1}:
#  1.0
#  1.0

# %%
hist = gradientDescent(f,x,0.1,0.1)
# Out:
# 2.0
# 7x2 DataFrames.DataFrame
# | Row | X        | Y        |
# |-----|----------|----------|
# | 1   | 1.0      | 1.0      |
# | 2   | 0.799    | 0.799    |
# | 3   | 0.6382   | 0.6382   |
# | 4   | 0.50956  | 0.50956  |
# | 5   | 0.406648 | 0.406648 |
# | 6   | 0.324318 | 0.324318 |
# | 7   | 0.258455 | 0.258455 |

# %%
plot(hist, x="X", y="Y", Geom.line)
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in call at /Users/mburq/.julia/v0.4/Gadfly/src/coord.jl:46
#  in call at /Users/mburq/.julia/v0.4/Gadfly/src/coord.jl:43
#  in render_prepare at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:507
#  in render at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:781
#  in writemime at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:918
#  in sprint at iostream.jl:211
#  in display_dict at /Users/mburq/.julia/v0.4/IJulia/src/execute_request.jl:29
#  in execute_request_0x535c5df2 at /Users/mburq/.julia/v0.4/IJulia/src/execute_request.jl:212
#  in eventloop at /Users/mburq/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /Users/mburq/.julia/v0.4/IJulia/src/kernel.jl, in expression starting on line 31
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
# ...

# %%
 hist = Array(Float64, 0)
# Out:
# 0-element Array{Float64,1}

# %%
derivative(f,x,2,0.1)
# Out:
# 2.0999999999999996

# %%
gradient(f,x,0.1)
# Out:
# 2-element Array{Float64,1}:
#  2.1
#  2.1

# %%
gradientDescent(f,x,0.1,0.1)
# Out:
# 2.0
# 1.2768019999999927
# 0.8145984799999975
# 0.5193027871999982
# 0.3307251918079995
# 0.21036484915711942
# 0.13359768458055626

# %%
y=[2.0,1.0,-1.0]
function g(y)
    y[1]^2 + 3*y[2]^2 + 0.5*y[3]^2
end
# Out:
# g (generic function with 1 method)

# %%
derivative(g,y,1,0.1)
# Out:
# 4.100000000000001

# %%
gradient(f, y, 0.1)
# Out:
# 3-element Array{Float64,1}:
#  4.1
#  2.1
#  0.0

# %%
gradientDescent(g,y,0.1,0.01)
# Out:
# 7.5
# 3.4440052812503836
# 2.042463516112613
# 1.3260045812881776
# 0.8878434658130422
# 0.603801279852093
# 0.41586933326930076
# 0.2901032013573627
# 0.205084619810469
# 0.14699157179517164
# 0.1068277689485514
# 0.07870485822636375
# 0.05874700646884427
# 0.04438657178058494
# 0.033909675917678066
# 0.026162254741598202

# %%
function plotf(f)
    delta = 0.2
    rangeX = [-10:0.1:10;]
    rangeY = [-10:0.1:10;]
    Z = Array(Float64, size(rangeX)[1], size(rangeY)[1])
    for x in [1:size(rangeX)[1];]
        for y in [1:size(rangeY)[1];]
            a = [rangeX[x],rangeY[y]]
            Z[x,y] = f(a)
        end
    end
    plot(z=Z, x=rangeX, y=rangeY, Geom.contour)
end
# Out:
# plotf (generic function with 1 method)

# %%
using RDatasets
plot(dataset("datasets", "iris"), x="SepalLength", y="SepalWidth", Geom.point)
dataset("datasets", "iris")
# Out:
# 150x5 DataFrames.DataFrame
# | Row | SepalLength | SepalWidth | PetalLength | PetalWidth | Species     |
# |-----|-------------|------------|-------------|------------|-------------|
# | 1   | 5.1         | 3.5        | 1.4         | 0.2        | "setosa"    |
# | 2   | 4.9         | 3.0        | 1.4         | 0.2        | "setosa"    |
# | 3   | 4.7         | 3.2        | 1.3         | 0.2        | "setosa"    |
# | 4   | 4.6         | 3.1        | 1.5         | 0.2        | "setosa"    |
# | 5   | 5.0         | 3.6        | 1.4         | 0.2        | "setosa"    |
# | 6   | 5.4         | 3.9        | 1.7         | 0.4        | "setosa"    |
# | 7   | 4.6         | 3.4        | 1.4         | 0.3        | "setosa"    |
# | 8   | 5.0         | 3.4        | 1.5         | 0.2        | "setosa"    |
# | 9   | 4.4         | 2.9        | 1.4         | 0.2        | "setosa"    |
# | 10  | 4.9         | 3.1        | 1.5         | 0.1        | "setosa"    |
# ...

# %%
plotf(f)
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in call at /Users/mburq/.julia/v0.4/Gadfly/src/coord.jl:46
#  in call at /Users/mburq/.julia/v0.4/Gadfly/src/coord.jl:43
#  in render_prepare at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:507
#  in render at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:781
#  in writemime at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:918
#  in sprint at iostream.jl:211
#  in display_dict at /Users/mburq/.julia/v0.4/IJulia/src/execute_request.jl:29
#  in execute_request_0x535c5df2 at /Users/mburq/.julia/v0.4/IJulia/src/execute_request.jl:212
#  in eventloop at /Users/mburq/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading /Users/mburq/.julia/v0.4/IJulia/src/kernel.jl, in expression starting on line 31
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
# ...

# %%
volcano = float(array(dataset("datasets", "volcano")))
plot(z=volcano, Geom.contour)
# Out:
# WARNING: array(df::AbstractDataFrame) is deprecated, use convert(Array,df) instead.
#  in depwarn at deprecated.jl:73
#  in array at deprecated.jl:50
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /Users/mburq/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /Users/mburq/.julia/v0.4/IJulia/src/IJulia.jl:144
#  in anonymous at task.jl:447
# while loading In[47], in expression starting on line 1
# WARNING: Base.String is deprecated, use AbstractString instead.
# in set_mapped_data! at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:273
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn at deprecated.jl:73
#  in call at deprecated.jl:50
#  in call at /Users/mburq/.julia/v0.4/Gadfly/src/coord.jl:46
#  in call at /Users/mburq/.julia/v0.4/Gadfly/src/coord.jl:43
#  in render_prepare at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:507
#  in render at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:781
# ...

# %%
volcano
# Out:
# 87x61 Array{Float64,2}:
#  100.0  100.0  101.0  101.0  101.0  …  105.0  105.0  104.0  104.0  103.0
#  101.0  101.0  102.0  102.0  102.0     106.0  105.0  105.0  104.0  104.0
#  102.0  102.0  103.0  103.0  103.0     106.0  106.0  105.0  105.0  104.0
#  103.0  103.0  104.0  104.0  104.0     107.0  106.0  106.0  105.0  105.0
#  104.0  104.0  105.0  105.0  105.0     107.0  107.0  106.0  106.0  105.0
#  105.0  105.0  105.0  106.0  106.0  …  108.0  107.0  107.0  106.0  106.0
#  105.0  106.0  106.0  107.0  107.0     108.0  108.0  107.0  107.0  106.0
#  106.0  107.0  107.0  108.0  108.0     109.0  108.0  108.0  107.0  106.0
#  107.0  108.0  108.0  109.0  109.0     109.0  109.0  108.0  107.0  107.0
#  108.0  109.0  109.0  110.0  110.0     110.0  109.0  108.0  107.0  107.0
#  109.0  110.0  110.0  111.0  111.0  …  110.0  109.0  108.0  107.0  106.0
#  110.0  110.0  111.0  113.0  112.0     110.0  109.0  108.0  107.0  106.0
# ...

# %%
dataset("datasets", "volcano")
# Out:
# 87x61 DataFrames.DataFrame
# | Row | X1  | X2  | X3  | X4  | X5  | X6  | X7  | X8  | X9  | X10 | X11 | X12 |
# |-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | 1   | 100 | 100 | 101 | 101 | 101 | 101 | 101 | 100 | 100 | 100 | 101 | 101 |
# | 2   | 101 | 101 | 102 | 102 | 102 | 102 | 102 | 101 | 101 | 101 | 102 | 102 |
# | 3   | 102 | 102 | 103 | 103 | 103 | 103 | 103 | 102 | 102 | 102 | 103 | 103 |
# | 4   | 103 | 103 | 104 | 104 | 104 | 104 | 104 | 103 | 103 | 103 | 103 | 104 |
# | 5   | 104 | 104 | 105 | 105 | 105 | 105 | 105 | 104 | 104 | 103 | 104 | 104 |
# | 6   | 105 | 105 | 105 | 106 | 106 | 106 | 106 | 105 | 105 | 104 | 104 | 105 |
# | 7   | 105 | 106 | 106 | 107 | 107 | 107 | 107 | 106 | 106 | 105 | 105 | 106 |
# | 8   | 106 | 107 | 107 | 108 | 108 | 108 | 108 | 107 | 107 | 106 | 106 | 107 |
# | 9   | 107 | 108 | 108 | 109 | 109 | 109 | 109 | 108 | 108 | 107 | 108 | 108 |
# ...

# %%
plotf(f)
# Out:
# 40401x3 DataFrames.DataFrame
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
# TypeError: setfield!: expected Union{Array{T,2},Function,Void}, got DataArrays.DataArray{Float64,1}
#
#  in apply_scale at /Users/mburq/.julia/v0.4/Gadfly/src/scale.jl:790
#  in apply_scales at /Users/mburq/.julia/v0.4/Gadfly/src/scale.jl:39
#  in apply_scales at /Users/mburq/.julia/v0.4/Gadfly/src/scale.jl:59
#  in render_prepare at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:715
#  in render at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:781
#  in writemime at /Users/mburq/.julia/v0.4/Gadfly/src/Gadfly.jl:918
#  in sprint at iostream.jl:211
#  in display_dict at /Users/mburq/.julia/v0.4/IJulia/src/execute_request.jl:29
# | Row   | X     | Y     | Z      |
# |-------|-------|-------|--------|
# | 1     | -10.0 | -10.0 | 200.0  |
# | 2     | -10.0 | -9.9  | 198.01 |
# | 3     | -10.0 | -9.8  | 196.04 |
# | 4     | -10.0 | -9.7  | 194.09 |
# | 5     | -10.0 | -9.6  | 192.16 |
# ...

# %% [markdown]
# ## Exo 2

# %% [markdown]
# ## Exo 3

# %%
2+4
